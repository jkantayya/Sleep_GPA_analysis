# %% [markdown]
# ## IDSC

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cmu-sleep.csv")
df
# Out:
#      subject_id  study cohort demo_race demo_gender demo_firstgen  \
# 0           185      5   lac1         1           1             0
# 1           158      5   lac1         0           1             0
# 2           209      5   lac1         1           1             0
# 3           102      5   lac1         0           1             1
# 4           174      5   lac1         1           1             0
# ..          ...    ...    ...       ...         ...           ...
# 629       99978      4     nh         0           0             0
# 630          61      2    uw1         0           1
# 631         172      2    uw1         1           1
# 632         110      2    uw1         1           0
# 633       84390      4     nh         1           1
#
#      bedtime_mssd  TotalSleepTime  midpoint_sleep  frac_nights_with_data  \
# 0        0.116727      432.200000      458.660000               0.862069
# 1        0.141681      391.931035      364.465517               1.000000
# ...

# %%
df.demo_firstgen.unique()
# Out:
# array(['0', '1', '2', ' '], dtype=object)

# %%
df.shape
# Out:
# (634, 15)

# %%
# cleaning the firstgen column
df['demo_firstgen'] = df['demo_firstgen'].replace([' ', '2'], np.nan)

df = df.dropna(subset=['demo_firstgen'])
df.shape
# Out:
# (629, 15)

# %%
df.demo_firstgen.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
sns.boxplot(data=df, x='demo_firstgen', y='term_gpa', palette="Set2")
plt.xticks([0, 1], ['Non-First Gen', 'First Gen'])
plt.title("Term GPA by First-Generation Status")
plt.xlabel("First-Generation Status")
plt.ylabel("Term GPA")
plt.ylim(2, 4.0)
plt.show()
# Out:
# C:\Users\muffi\AppData\Local\Temp\ipykernel_18212\2415860914.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='demo_firstgen', y='term_gpa', palette="Set2")

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['demo_firstgen'] == '0']['term_gpa'], kde=True, color='blue', label='Non-First Gen', stat="density", linewidth=0)
sns.histplot(df[df['demo_firstgen'] == '1']['term_gpa'], kde=True, color='orange', label='First Gen', stat="density", linewidth=0)
plt.legend()
plt.title("Term GPA Distribution by First-Generation Status")
plt.xlabel("Term GPA")
plt.ylabel("Density")
plt.show()

# %%
df['demo_gender'] = df['demo_gender'].replace([' ','2'], np.nan)

df = df.dropna(subset=['demo_gender'])
# Out:
# C:\Users\muffi\AppData\Local\Temp\ipykernel_18212\485383346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['demo_gender'] = df['demo_gender'].replace([' ','2'], np.nan)

# %%
sns.boxplot(data=df, x='demo_gender', y='term_gpa', palette="Set2")
plt.xticks([0, 1], ['Male', 'Female'])
plt.title("Term GPA by Gender")
plt.xlabel("Gender")
plt.ylabel("Term GPA")
plt.ylim(2, 4.0)
plt.show()
# Out:
# C:\Users\muffi\AppData\Local\Temp\ipykernel_18212\3965706243.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='demo_gender', y='term_gpa', palette="Set2")

# %%
df['demo_race'] = df['demo_race'].replace([' ','2'], np.nan)

df = df.dropna(subset=['demo_race'])

# %%
df['demo_gender'].unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
sns.boxplot(data=df, x='demo_race', y='term_gpa', palette="Set2")
plt.xticks([0, 1], ['Underrepresented Race', 'Non Underrepresented Race'])
plt.title("Term GPA Distribution by Underrepresented Race Status")
plt.xlabel("")
plt.ylabel("Term GPA")
plt.ylim(2, 4.0)
plt.show()
# Out:
# C:\Users\muffi\AppData\Local\Temp\ipykernel_18212\523376238.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='demo_race', y='term_gpa', palette="Set2")
